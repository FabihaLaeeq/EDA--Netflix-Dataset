# %%
import zipfile

with zipfile.ZipFile("netflix_titles.csv.zip", "r") as zip_ref:
    zip_ref.extractall()

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Dataset
df = pd.read_csv("netflix_titles.csv")

# %%
#View Data
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
df.sample(15)
# Out:
#      show_id     type                                              title  \
# 2958   s2959  TV Show  Is It Wrong to Try to Pick Up Girls in a Dungeon?
# 6059   s6060    Movie                        A Tale of Love and Darkness
# 3281   s3282  TV Show                                       The Stranded
# 2470   s2471  TV Show                                          Supergirl
# 7585   s7586    Movie                                       Nightcrawler
# 5957   s5958    Movie                               To and From New York
# 8061   s8062    Movie                                        Sour Grapes
# 4448   s4449    Movie                                        Katti Batti
# 5397   s5398  TV Show  Learning Songs by Little Baby Bum: Nursery Rhy...
# 1709   s1710    Movie                                         First Love
# 1054   s1055    Movie     Wave of Cinema: One Day We'll Talk About Today
# 5587   s5588    Movie                                            Force 2
# 8097   s8098  TV Show                   Storage Wars: Northern Treasures
# 1226   s1227  TV Show                                      The Houseboat
# 578     s579    Movie                                Memoirs of a Geisha
#
#                           director  \
# 2958                           NaN
# 6059               Natalie Portman
# 3281                           NaN
# 2470                    Jesse Warn
# 7585                    Dan Gilroy
# 5957          Sorin Dan Mihalcescu
# 8061  Jerry Rothwell, Reuben Atlas
# 4448                 Nikhil Advani
# 5397                           NaN
# 1709                  Paul Soriano
# 1054               Adriano Rudiman
# 5587                   Abhinay Deo
# 8097                           NaN
# 1226                           NaN
# 578                   Rob Marshall
#
#                                                    cast  \
# 2958  Yoshitsugu Matsuoka, Inori Minase, Saori Onish...
# 6059  Natalie Portman, Gilad Kahana, Amir Tessler, M...
# 3281  Papangkorn Lerkchaleampote, Chayanit Chansanga...
# 2470  Melissa Benoist, Mehcad Brooks, Chyler Leigh, ...
# 7585  Jake Gyllenhaal, Rene Russo, Riz Ahmed, Bill P...
# 5957  Barbara King, Shaana Diya, John Krisiukenas, Y...
# 8061                                                NaN
# 4448  Imran Khan, Kangana Ranaut, Abhishek Saha, Mit...
# 5397          Chloe Marsden, Aaron Marsden, María Esnoz
# 1709  Aga Muhlach, Bea Alonzo, Sandy Andolong, Albie...
# 1054  Isyana Sarasvati, Kunto Aji, Sisir Tanah, Chik...
# 5587  John Abraham, Sonakshi Sinha, Tahir Raj Bhasin...
# 8097  Ursula Stolf, Paul Kenny, Bogart Kenny, Roy Di...
# 1226                         Olli Schulz, Fynn Kliemann
# 578   Zhang Ziyi, Ken Watanabe, Koji Yakusho, Michel...
#
#                            country         date_added  release_year rating  \
# 2958                         Japan   February 1, 2020          2015  TV-MA
# 6059         Israel, United States   October 25, 2019          2015  PG-13
# 3281                      Thailand  November 15, 2019          2019  TV-MA
# 2470                 United States       May 25, 2020          2019  TV-14
# 7585                 United States    August 10, 2020          2014      R
# 5957                 United States    January 1, 2008          2006  TV-MA
# 8061                United Kingdom  November 18, 2016          2016     NR
# 4448                         India   November 1, 2018          2015  TV-14
# 5397                United Kingdom       July 1, 2017          2015   TV-Y
# 1709                   Philippines  November 12, 2020          2018  TV-MA
# 1054                           NaN     April 15, 2021          2020  TV-14
# 5587                         India  February 27, 2017          2016  TV-14
# 8097                 United States      July 22, 2019          2015  TV-MA
# 1226                       Germany      March 9, 2021          2021  TV-14
# 578   France, Japan, United States       July 1, 2021          2005  PG-13
#
#        duration                                          listed_in  \
# 2958   1 Season               Anime Series, International TV Shows
# 6059     98 min                       Dramas, International Movies
# 3281   1 Season  International TV Shows, TV Action & Adventure,...
# 2470  5 Seasons         TV Action & Adventure, TV Sci-Fi & Fantasy
# 7585    118 min              Dramas, Independent Movies, Thrillers
# 5957     81 min              Dramas, Independent Movies, Thrillers
# 8061     85 min                                      Documentaries
# 4448    132 min             Comedies, Dramas, International Movies
# 5397   1 Season                         British TV Shows, Kids' TV
# 1709    123 min      Dramas, International Movies, Romantic Movies
# 1054     71 min  Documentaries, International Movies, Music & M...
# 5587    123 min           Action & Adventure, International Movies
# 8097   1 Season                 International TV Shows, Reality TV
# 1226   1 Season                 Docuseries, International TV Shows
# 578     145 min                            Dramas, Romantic Movies
#
#                                             description
# 2958  Lovable goof Bell Cranel wants an adventure, a...
# 6059  Based on the memoirs of author Amos Oz, this p...
# 3281  Trapped on an island destroyed by a tsunami, t...
# 2470  To avert a disaster, Kara Danvers reveals her ...
# 7585  A young hustler finds success trolling the str...
# 5957  While covering a story in New York City, a Sea...
# 8061  A dizzying chronicle of excess and deception d...
# 4448  After falling in love during college, architec...
# 5397  Simple songs mix with colorful animation to te...
# 1709  A chance encounter soon intertwines the lives ...
# 1054  Delve into a musical concert and relive moment...
# 5587  An ex-cop investigates the death of his best f...
# 8097  In Canada, a colorful collection of treasure-s...
# 1226  With plenty of passion and little know-how, tw...
# 578   Sold to a geisha house as a child, a fisherman...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.select_dtypes(include="object").columns:
    print(f"\n{col}")
    print(df[col].unique())

# %%
df.columns = df.columns.str.strip()

# %%
df["director"].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipykernel_1407/1629569822.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["director"].fillna("Unknown", inplace=True)

# %%
df["cast"].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipykernel_1407/645868371.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cast"].fillna("Unknown", inplace=True)

# %%
df["country"].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipykernel_1407/817232404.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["country"].fillna("Unknown", inplace=True)

# %%
#drop missing dates
df.dropna(subset=["date_added"], inplace=True)

# %%
df["rating"].fillna(df["rating"].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_1407/3860191944.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["rating"].fillna(df["rating"].mode()[0], inplace=True)

# %%
df["duration"].fillna(df["duration"].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_1407/897029669.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["duration"].fillna(df["duration"].mode()[0], inplace=True)

# %%
df[df["rating"].str.contains("min", na=False)]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#       duration listed_in                                        description
# 5541  1 Season    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794  1 Season    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813  1 Season    Movies  The comic puts his trademark hilarious/thought...

# %%
df = df[~df["rating"].str.contains("min", na=False)]

# %%
df[df["rating"].str.contains("min", na=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df["date_added"] = df["date_added"].str.strip()

# %%
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8794 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8794 non-null   object
#  1   type          8794 non-null   object
#  2   title         8794 non-null   object
#  3   director      8794 non-null   object
#  4   cast          8794 non-null   object
#  5   country       8794 non-null   object
#  6   date_added    8794 non-null   datetime64[ns]
#  7   release_year  8794 non-null   int64
#  8   rating        8794 non-null   object
#  9   duration      8794 non-null   object
#  10  listed_in     8794 non-null   object
#  11  description   8794 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 893.1+ KB

# %%
#For Data Visualization

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6128
# TV Show    2666
# Name: count, dtype: int64

# %%
df["country"].value_counts().head(15)
# Out:
# country
# United States     2809
# India              972
# Unknown            830
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Turkey             105
# Nigeria             95
# Australia           86
# Taiwan              81
# Name: count, dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       3209
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
df["country"].value_counts().head(10).plot(kind="bar")

plt.title("Top 10 Countries")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(y="rating", data=df)

plt.title("Content Ratings")
plt.show()

# %%
plt.figure(figsize=(12,5))

sns.histplot(df["release_year"], bins=30)

plt.title("Release Year Distribution")
plt.show()

# %%
df["release_year"].value_counts().sort_index().plot()

plt.title("Netflix Content by Release Year")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.show()
